# %% [markdown]
# <a href="https://colab.research.google.com/github/saxena431/Sareni2/blob/main/Sareni3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
df=pd.read_excel("/content/Try4.xlsx")

# %%
df.head(1)
# Out:
#                   name                 creation                         User  \
# 0  Sareni_Survey000165  03/12/2026, 12:47:28 PM  ankitpandit808127@gmail.com
#
#                                             Location       Audio  Booth No  \
# 0  {"type":"FeatureCollection","features":[{"type...  View Audio       115
#
#   Area/Village/Town        Name Father Name   Mobile No  ...  \
# 0        hamirgaon   kesh wati      rajjan   9696070369  ...
#
#    Other (other_que_11)  \
# 0                   NaN
#
#   1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?  \
# 0                                              बिजली
#
#   2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?  \
# 0                                 बेरोजगारी
#
#   3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?  \
# 0                                      थोडा बहुत
#
#   4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  \
# 0                                                BSP
#
#   5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?  \
# 0                              ठाकुर प्रसाद यादव-BSP
#
#   6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?  \
# 0                   BSP- सरकार(मायावती)  (2007-2012)
#
#   7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?  \
# 0                                     सुश्री.मायावती
#
#    Remark Vendor Name
# 0  light        anamd
#
# [1 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 26 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   name                                                                                 134 non-null    object
#  1   creation                                                                             134 non-null    object
#  2   User                                                                                 134 non-null    object
#  3   Location                                                                             134 non-null    object
#  4   Audio                                                                                134 non-null    object
#  5   Booth No                                                                             134 non-null    int64
#  6   Area/Village/Town                                                                    134 non-null    object
#  7   Name                                                                                 134 non-null    object
#  8   Father Name                                                                          134 non-null    object
#  9   Mobile No                                                                            134 non-null    int64
#  10  Age                                                                                  134 non-null    int64
#  11  Gender                                                                               134 non-null    object
#  12  Education                                                                            134 non-null    object
#  13  Occupation                                                                           134 non-null    object
#  14  Category                                                                             134 non-null    object
#  15  Caste                                                                                134 non-null    object
#  16  Other (other_que_11)                                                                 36 non-null     object
#  17  1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?  134 non-null    object
#  18  2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?                                            134 non-null    object
#  19  3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?                                       134 non-null    object
#  20  4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?            134 non-null    object
#  21  5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?         134 non-null    object
#  22  6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?                                134 non-null    object
#  23  7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?                134 non-null    object
#  24  Remark                                                                               134 non-null    object
#  25  Vendor Name                                                                          134 non-null    object
# dtypes: int64(3), object(23)
# memory usage: 27.3+ KB

# %%
df.describe()
# Out:
#          Booth No     Mobile No         Age
# count  134.000000  1.340000e+02  134.000000
# mean   105.410448  8.593681e+09   47.186567
# std      5.426491  9.147442e+08   15.623949
# min    100.000000  6.393464e+09   19.000000
# 25%    102.000000  7.889655e+09   33.500000
# 50%    104.000000  8.826749e+09   49.000000
# 75%    106.000000  9.451703e+09   59.750000
# max    117.000000  9.988513e+09   88.000000

# %%
df.isna().sum()
# Out:
# name                                                                                    0
# creation                                                                                0
# User                                                                                    0
# Location                                                                                0
# Audio                                                                                   0
# Booth No                                                                                0
# Area/Village/Town                                                                       0
# Name                                                                                    0
# Father Name                                                                             0
# Mobile No                                                                               0
# Age                                                                                     0
# Gender                                                                                  0
# Education                                                                               0
# Occupation                                                                              0
# Category                                                                                0
# Caste                                                                                   0
# Other (other_que_11)                                                                   98
# 1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?     0
# 2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?                                               0
# 3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?                                          0
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?               0
# 5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?            0
# 6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?                                   0
# 7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?                   0
# Remark                                                                                  0
# Vendor Name                                                                             0
# dtype: int64

# %%
df.fillna('0')
# Out:
#                     name                 creation  \
# 0    Sareni_Survey000165  03/12/2026, 12:47:28 PM
# 1    Sareni_Survey000164  03/12/2026, 12:43:42 PM
# 2    Sareni_Survey000163  03/12/2026, 12:34:16 PM
# 3    Sareni_Survey000162  03/12/2026, 12:21:17 PM
# 4    Sareni_Survey000161  03/12/2026, 12:12:44 PM
# ..                   ...                      ...
# 129  Sareni_Survey000021  03/10/2026, 09:59:29 AM
# 130  Sareni_Survey000020  03/10/2026, 09:49:23 AM
# 131  Sareni_Survey000018  03/10/2026, 09:33:44 AM
# 132  Sareni_Survey000017  03/10/2026, 09:28:06 AM
# 133  Sareni_Survey000016  03/10/2026, 09:17:18 AM
#
#                               User  \
# 0      ankitpandit808127@gmail.com
# 1      ankitpandit808127@gmail.com
# 2      ankitpandit808127@gmail.com
# 3      ankitpandit808127@gmail.com
# 4    diwakarshukla941586@gmail.com
# ..                             ...
# 129    sanataniradmohan@gmail.coml
# 130    sanataniradmohan@gmail.coml
# 131  diwakarshukla941586@gmail.com
# 132    sanataniradmohan@gmail.coml
# 133    sanataniradmohan@gmail.coml
#
#                                               Location       Audio  Booth No  \
# 0    {"type":"FeatureCollection","features":[{"type...  View Audio       115
# 1    {"type":"FeatureCollection","features":[{"type...  View Audio       115
# 2    {"type":"FeatureCollection","features":[{"type...  View Audio       115
# 3    {"type":"FeatureCollection","features":[{"type...  View Audio       115
# 4    {"type":"FeatureCollection","features":[{"type...  View Audio       106
# ..                                                 ...         ...       ...
# 129  {"type":"FeatureCollection","features":[{"type...  View Audio       101
# 130  {"type":"FeatureCollection","features":[{"type...  View Audio       101
# 131         {"type":"FeatureCollection","features":[]}  View Audio       102
# 132  {"type":"FeatureCollection","features":[{"type...  View Audio       101
# 133  {"type":"FeatureCollection","features":[{"type...  View Audio       101
#
#     Area/Village/Town           Name      Father Name   Mobile No  ...  \
# 0          hamirgaon      kesh wati           rajjan   9696070369  ...
# 1          hamirgaon       sree ram          chature   8367107950  ...
# 2          hamirgaon      anju davi      vinod kumar   9936847758  ...
# 3          hamirgaon   sangeta davi     parmod kumar   8400962840  ...
# 4       gopali kahera    mathu dvidi      suras dvidi  9451502873  ...
# ..                ...            ...              ...         ...  ...
# 129          cheulaha      anitadevi       ajay kumar  8115562135  ...
# 130          cheulaha      shree pal         shitaram  7054056914  ...
# 131         cheulaha       ram badan  sangatha prasad  8736094315  ...
# 132          cheulaha         budhai            parag  8953867840  ...
# 133          cheulaha   rahul mshrai    rajesh meshra  7518709382  ...
#
#      Other (other_que_11)  \
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0
# ..                    ...
# 129                     0
# 130                     0
# 131                 dhobi
# 132                     0
# 133                     0
#
#     1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?  \
# 0                                                बिजली
# 1                                         पीने का पानी
# 2                                                 अन्य
# 3                                         पीने का पानी
# 4                                                बिजली
# ..                                                 ...
# 129                                           साफ.सफाई
# 130                                       पीने का पानी
# 131                                       पीने का पानी
# 132                                           साफ.सफाई
# 133                               स्वास्थ्य - हॉस्पिटल
#
#     2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?  \
# 0                                   बेरोजगारी
# 1                                   बेरोजगारी
# 2                                       Other
# 3                                   बेरोजगारी
# 4                                   आवारा पशु
# ..                                        ...
# 129                                     Other
# 130                                 बेरोजगारी
# 131                                 उधोग धंदे
# 132                                 बेरोजगारी
# 133                                 बेरोजगारी
#
#     3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?  \
# 0                                        थोडा बहुत
# 1                                     बिल्कुल नहीं
# 2                                 कुछ कह नहीं सकते
# 3                                 कुछ कह नहीं सकते
# 4                                      हाँ खुश हैं
# ..                                             ...
# 129                                    हाँ खुश हैं
# 130                                      थोडा बहुत
# 131                                   बिल्कुल नहीं
# 132                               कुछ कह नहीं सकते
# 133                                   बिल्कुल नहीं
#
#     4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  \
# 0                                                  BSP
# 1                                                  BSP
# 2                                                Other
# 3                                                Other
# 4                                                  BJP
# ..                                                 ...
# 129                                                BJP
# 130                                                INC
# 131                                                INC
# 132                                              Other
# 133                                              Other
#
#     5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?  \
# 0                                ठाकुर प्रसाद यादव-BSP
# 1                                ठाकुर प्रसाद यादव-BSP
# 2                                                Other
# 3                                                Other
# 4                          धीरेन्द्र बहादुर सिंह - BJP
# ..                                                 ...
# 129                                              Other
# 130                                  सुधा द्विवेदी-INC
# 131                                  सुधा द्विवेदी-INC
# 132                                 अमित सिंह वत्स-BJP
# 133                        धीरेन्द्र बहादुर सिंह - BJP
#
#     6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?  \
# 0                     BSP- सरकार(मायावती)  (2007-2012)
# 1                     BSP- सरकार(मायावती)  (2007-2012)
# 2                                             पता नहीं
# 3                                             पता नहीं
# 4          BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)
# ..                                                 ...
# 129        BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)
# 130                SP- सरकार (अखिलेश यादव) (2012-2017)
# 131                                           पता नहीं
# 132        BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)
# 133        BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)
#
#     7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?  \
# 0                                       सुश्री.मायावती
# 1                                       सुश्री.मायावती
# 2                                                 अन्य
# 3                                                 अन्य
# 4                                       योगी आदित्यनाथ
# ..                                                 ...
# 129                                     योगी आदित्यनाथ
# 130                                        अखिलेश यादव
# 131                                     सुश्री.मायावती
# 132                                     योगी आदित्यनाथ
# 133                                     योगी आदित्यनाथ
#
#                                               Remark Vendor Name
# 0                                             light        anamd
# 1                                              pani       anand
# 2                                              pani       anand
# 3                                              pani       anand
# 4                                              bijli      anannd
# ..                                               ...         ...
# 129                                nali ki saf safai      anand
# 130                                  pani  saf safai       anand
# 131                                  pani ki samsaya     diwakar
# 132  nali rod ki saf tal saf safai bhe nehi hoti hai       anand
# 133                                         pani ki        anand
#
# [134 rows x 26 columns]

# %%
df.isna().sum()
# Out:
# name                                                                                    0
# creation                                                                                0
# User                                                                                    0
# Location                                                                                0
# Audio                                                                                   0
# Booth No                                                                                0
# Area/Village/Town                                                                       0
# Name                                                                                    0
# Father Name                                                                             0
# Mobile No                                                                               0
# Age                                                                                     0
# Gender                                                                                  0
# Education                                                                               0
# Occupation                                                                              0
# Category                                                                                0
# Caste                                                                                   0
# Other (other_que_11)                                                                   98
# 1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?     0
# 2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?                                               0
# 3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?                                          0
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?               0
# 5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?            0
# 6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?                                   0
# 7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?                   0
# Remark                                                                                  0
# Vendor Name                                                                             0
# dtype: int64

# %%
print("Rows :",df.shape[0])
print("Columns :",df.shape[1])
# Out:
# Rows : 134
# Columns : 26

# %%
df.columns
# Out:
# Index(['name', 'creation', 'User', 'Location', 'Audio', 'Booth No',
#        'Area/Village/Town', 'Name', 'Father Name', 'Mobile No', 'Age',
#        'Gender', 'Education', 'Occupation', 'Category', 'Caste',
#        'Other (other_que_11)',
#        '1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?',
#        '2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?',
#        '3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?',
#        '4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?',
#        '5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?',
#        '6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?',
#        '7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?',
#        'Remark', 'Vendor Name'],
#       dtype='object')

# %%
df["Gender"].value_counts()
# Out:
# Gender
# MALE      87
# FEMALE    47
# Name: count, dtype: int64

# %%
sns.countplot(x="Gender",data=df,palette='dark')
# Out:
# /tmp/ipykernel_319/344270840.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df["Education"].value_counts()
# Out:
# Education
# Other            56
# 10th             39
# Graduate         16
# 12th             13
# Post Graduate    10
# Name: count, dtype: int64

# %%
sns.countplot(x="Education",data=df,palette='dark')
# Out:
# /tmp/ipykernel_319/1174299621.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <Axes: xlabel='Education', ylabel='count'>

# %%
df["Category"].value_counts()
# Out:
# Category
# पिछड़ा             66
# सामान्य            32
# अनुसुचित जाति      32
# मुस्लिम             2
# अनुसुचितजन जाति     1
# अन्य                1
# Name: count, dtype: int64

# %%
fig3=px.histogram(df,x="Category",barmode='group')
fig3.update_layout(xaxis_title="Category",yaxis_title="Count",title="Chart for Category")
fig3
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="12b8690d-fb53-4712-b71b-a3aa9ebdafb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12b8690d-fb53-4712-b71b-a3aa9ebdafb7")) {                    Plotly.newPlot(                        "12b8690d-fb53-4712-b71b-a3aa9ebdafb7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Category=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","सामान्य","सामान्य","पिछड़ा","पिछड़ा","सामान्य","अनुसुचित जाति","सामान्य","पिछड़ा","पिछड़ा","अनुसुचितजन जाति","सामान्य","पिछड़ा","पिछड़ा","सामान्य","पिछड़ा","सामान्य","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","अनुसुचित जाति","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","सामान्य","पिछड़ा","पिछड़ा","पिछड़ा","अनुसुचित जाति","पिछड़ा","पिछड़ा","अनुसुचित जाति","पिछड़ा","अनुसुचित जाति","सामान्य","अनुसुचित जाति","अनुसुचित जाति","पिछड़ा","पिछड़ा","अनुसुचित जाति","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","पिछड़ा","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","सामान्य","सामान्य","सामान्य","सामान्य","पिछड़ा","पिछड़ा","पिछड़ा","सामान्य","पिछड़ा","सामान्य","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","मुस्लिम","पिछड़ा","अनुसुचित जाति","सामान्य","पिछड़ा","अनुसुचित जाति","पिछड़ा","सामान्य","पिछड़ा","सामान्य","अनुसुचित जाति","पिछड़ा","पिछड़ा","पिछड़ा","सामान्य","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","अनुसुचित जाति","अनुसुचित जाति","पिछड़ा","पिछड़ा","पिछड़ा","अन्य","पिछड़ा","पिछड़ा","अनुसुचित जाति","पिछड़ा","पिछड़ा","सामान्य","अनुसुचित जाति","सामान्य","पिछड़ा","सामान्य","अनुसुचित जाति","सामान्य","सामान्य","सामान्य","सामान्य","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","सामान्य","सामान्य","अनुसुचित जाति","अनुसुचित जाति","मुस्लिम","सामान्य","सामान्य","सामान्य","अनुसुचित जाति","पिछड़ा","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","अनुसुचित जाति","सामान्य"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"t ...

# %%
df.columns
# Out:
# Index(['name', 'creation', 'User', 'Location', 'Audio', 'Booth No',
#        'Area/Village/Town', 'Name', 'Father Name', 'Mobile No', 'Age',
#        'Gender', 'Education', 'Occupation', 'Category', 'Caste',
#        'Other (other_que_11)',
#        '1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?',
#        '2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?',
#        '3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?',
#        '4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?',
#        '5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?',
#        '6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?',
#        '7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?',
#        'Remark', 'Vendor Name'],
#       dtype='object')

# %%
df["Occupation"].value_counts()
# Out:
# Occupation
# Farmer         64
# Other          46
# Private Job    14
# Business        6
# Shopkeepers     3
# Gov. Job        1
# Name: count, dtype: int64

# %%
sns.countplot(x="Occupation",data=df,palette='dark')
# Out:
# /tmp/ipykernel_319/2501655489.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df["Caste"].value_counts()
# Out:
# Caste
# Others            50
# हरिजन (जाटव)      33
# ब्राहमण           29
# खाती / बढ़ई         7
# यादव               4
# नाई/सविता          4
# मुस्लिम            2
# ठाकुर / राजपुत     2
# लोधी               1
# कुर्मी / पटेल      1
# तेली/ गुप्ता       1
# Name: count, dtype: int64

# %%
fig2=px.histogram(df,x="Caste",color="Gender",barmode="group")
fig2.update_layout(xaxis_title="Caste",yaxis_title="Gender",title="Chart for Gender and Caste")
fig2
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dffb9fc1-08f3-480b-bedd-4b3fa17c16f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dffb9fc1-08f3-480b-bedd-4b3fa17c16f9")) {                    Plotly.newPlot(                        "dffb9fc1-08f3-480b-bedd-4b3fa17c16f9",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"
%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["हरिजन (जाटव)","हरिजन (जाटव)","लोधी","कुर्मी \u002f पटेल","ब्राहमण","ब्राहमण","Others","Others","ब्राहमण","Others","ब्राहमण","यादव","यादव","नाई\u002fसविता","ब्राहमण","Others","Others","ब्राहमण","Others","ब्राहमण","नाई\u002fसविता","Others","Others","यादव","Others","Others","Others","हरिजन (जाटव)","खाती \u002f बढ़ई","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","Others","हरिजन (जाटव)","हरिजन (जाटव)","Others","हरिजन (जाटव)","ब्राहमण","Others","हरिजन (जाटव)","हरिजन (जाटव)","Others","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","Others","हरिजन (जाटव)","Others","Others","Others","ब्राहमण","ब्राहमण","ब्राहमण","ब्राहमण","हरिजन (जाटव)","Others","हरिजन (जाटव)","ब्राहमण","हरिजन (जाटव)","ब्राहमण","हरिजन (जाटव)","हरिजन (जाटव)","नाई\u002fसविता","हरिजन (जाटव)","Others","Others","Others","Others","मुस्लिम","Others","Others","ब्राहमण","Others","Others","यादव","ब्राहमण","Others","ठाकुर \u002f राजपुत","हरिजन (जाटव)","Others","Others","खाती \u002f बढ़ई","ब्राहमण","Others","Others","Others","Others","Others","तेली\u002f गुप्ता","खाती \u002f बढ़ई","खाती \u002f बढ़ई","Others","खाती \u002f बढ़ई","खाती \u002f बढ़ई","Others","Others","खाती \u002f बढ़ई","ब्राहमण","Others","ब्राहमण","Others","ब्राहमण","Others","ब्राहमण","ब्राहमण","ब्राहमण","ब्राहमण","हरिजन (जाटव)","Others","Others","ब्राहमण","ठाकुर \u002f राजपुत","Others","हरिजन (जाटव)","मुस्लिम","ब्राहमण","ब्राहमण","ब्राहमण","Others","नाई\u002fसविता","Others","Others","Others","Others","ब्राहमण"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777 ...

# %%
df["4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?"].value_counts()
# Out:
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?
# BJP      39
# Other    38
# BSP      24
# SP       21
# INC      12
# Name: count, dtype: int64

# %%
sns.countplot(x="4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?",data=df,palette='dark')
plt.xlabel("Party")
plt.ylabel("Voting Count")
# Out:
# /tmp/ipykernel_319/2483409755.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# Text(0, 0.5, 'Voting Count')

# %%
df.groupby("Booth No")["4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?"].value_counts().unstack(fill_value=0)
# Out:
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  BJP  \
# Booth No
# 100                                                                          2
# 101                                                                          5
# 102                                                                          8
# 103                                                                          1
# 104                                                                          4
# 105                                                                          6
# 106                                                                          6
# 115                                                                          2
# 116                                                                          5
# 117                                                                          0
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  BSP  \
# Booth No
# 100                                                                          0
# 101                                                                          0
# 102                                                                          1
# 103                                                                          5
# 104                                                                          4
# 105                                                                          3
# 106                                                                          0
# 115                                                                          3
# 116                                                                          8
# 117                                                                          0
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  INC  \
# Booth No
# 100                                                                          0
# 101                                                                          2
# 102                                                                          5
# 103                                                                          0
# 104                                                                          3
# 105                                                                          0
# 106                                                                          2
# 115                                                                          0
# 116                                                                          0
# 117                                                                          0
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  Other  \
# Booth No
# 100                                                                            7
# 101                                                                           11
# 102                                                                            5
# 103                                                                            0
# 104                                                                            8
# 105                                                                            2
# 106                                                                            0
# 115                                                                            4
# 116                                                                            0
# 117                                                                            1
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  SP
# Booth No
# 100                                                                         1
# 101                                                                         3
# 102                                                                         3
# 103                                                                         4
# 104                                                                         4
# 105                                                                         0
# 106                                                                         2
# 115                                                                         2
# 116                                                                         1
# 117                                                                         1

# %%
df.groupby("Caste")["4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?"].value_counts(). unstack(fill_value=0)
# Out:
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  BJP  \
# Caste
# Others                                                                      15
# कुर्मी / पटेल                                                                0
# खाती / बढ़ई                                                                   4
# ठाकुर / राजपुत                                                               1
# तेली/ गुप्ता                                                                 1
# नाई/सविता                                                                    0
# ब्राहमण                                                                     14
# मुस्लिम                                                                      0
# यादव                                                                         0
# लोधी                                                                         0
# हरिजन (जाटव)                                                                 4
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  BSP  \
# Caste
# Others                                                                       7
# कुर्मी / पटेल                                                                0
# खाती / बढ़ई                                                                   0
# ठाकुर / राजपुत                                                               0
# तेली/ गुप्ता                                                                 0
# नाई/सविता                                                                    0
# ब्राहमण                                                                      0
# मुस्लिम                                                                      0
# यादव                                                                         0
# लोधी                                                                         0
# हरिजन (जाटव)                                                                17
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  INC  \
# Caste
# Others                                                                       6
# कुर्मी / पटेल                                                                0
# खाती / बढ़ई                                                                   1
# ठाकुर / राजपुत                                                               0
# तेली/ गुप्ता                                                                 0
# नाई/सविता                                                                    1
# ब्राहमण                                                                      1
# मुस्लिम                                                                      0
# यादव                                                                         0
# लोधी                                                                         0
# हरिजन (जाटव)                                                                 3
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  Other  \
# Caste
# Others                                                                        16
# कुर्मी / पटेल                                                                  1
# खाती / बढ़ई                                                                     2
# ठाकुर / राजपुत                                                                 0
# तेली/ गुप्ता                                                                   0
# नाई/सविता                                                                      3
# ब्राहमण                                                                       10
# मुस्लिम                                                                        1
# यादव                                                                           0
# लोधी                                                                           1
# हरिजन (जाटव)                                                                   4
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  SP
# Caste
# Others                                                                      6
# कुर्मी / पटेल                                                               0
# खाती / बढ़ई                                                                  0
# ठाकुर / राजपुत                                                              1
# तेली/ गुप्ता                                                                0
# नाई/सविता                                                                   0
# ब्राहमण                                                                     4
# मुस्लिम                                                                     1
# यादव                                                                        4
# लोधी                                                                        0
# हरिजन (जाटव)                                                                5

# %%
df.groupby("Category")["4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?"].value_counts().unstack(fill_value=0)
# Out:
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  BJP  \
# Category
# अनुसुचित जाति                                                                2
# अनुसुचितजन जाति                                                              0
# अन्य                                                                         0
# पिछड़ा                                                                      22
# मुस्लिम                                                                      0
# सामान्य                                                                     15
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  BSP  \
# Category
# अनुसुचित जाति                                                                2
# अनुसुचितजन जाति                                                              0
# अन्य                                                                         0
# पिछड़ा                                                                      21
# मुस्लिम                                                                      0
# सामान्य                                                                      1
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  INC  \
# Category
# अनुसुचित जाति                                                                7
# अनुसुचितजन जाति                                                              1
# अन्य                                                                         0
# पिछड़ा                                                                       3
# मुस्लिम                                                                      0
# सामान्य                                                                      1
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  Other  \
# Category
# अनुसुचित जाति                                                                 15
# अनुसुचितजन जाति                                                                0
# अन्य                                                                           1
# पिछड़ा                                                                        11
# मुस्लिम                                                                        1
# सामान्य                                                                       10
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  SP
# Category
# अनुसुचित जाति                                                               6
# अनुसुचितजन जाति                                                             0
# अन्य                                                                        0
# पिछड़ा                                                                      9
# मुस्लिम                                                                     1
# सामान्य                                                                     5

# %%
fig = px.histogram(
    df,
    x="Category",
    color="4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?",
    barmode="group"
)
fig.update_layout(
    xaxis_title="Category",
    yaxis_title="Count",
    title="पार्टी पसंद श्रेणी के अनुसार"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8351a8e3-8cbf-4c1f-99ac-b87f24f93c6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8351a8e3-8cbf-4c1f-99ac-b87f24f93c6d")) {                    Plotly.newPlot(                        "8351a8e3-8cbf-4c1f-99ac-b87f24f93c6d",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?=BSP\u003cbr\u003eCategory=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BSP","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"BSP","offsetgroup":"BSP","orientation":"v","showlegend":true,"x":["पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","सामान्य","पिछड़ा","पिछड़ा","अनुसुचित जाति","पिछड़ा","पिछड़ा","अनुसुचित जाति","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?=Other\u003cbr\u003eCategory=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"v","showlegend":true,"x":["पिछड़ा","पिछड़ा","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","अनुसुचित जाति","अनुसुचित जाति","सामान्य","सामान्य","पिछड़ा","अनुसुचित जाति","सामान्य","पिछड़ा","सामान्य","पिछड़ा","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","अन्य","पिछड़ा","अनुसुचित जाति","पिछड़ा","सामान्य","अनुसुचित जाति","सामान्य","सामान्य","सामान्य","अनुसुचित जाति","अनुसुचित जाति","मुस्लिम","सामान्य","अनुसुचित जाति","पिछड़ा","अनुसुचित जाति","सामान्य"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?=BJP\u003cbr\u003eCategory=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BJP","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"BJP","offsetgroup":"BJP","orientation":"v","showlegend":true,"x":["सामान्य","सामान्य","पिछड़ा","सामान्य","सामान्य","पिछड़ा","पिछड़ा","पिछड़ा","सामान्य","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","सामान्य","अनुसुचित जाति","पिछड़ा","पिछड़ा","पिछड़ा","सामान्य","सामान्य","पिछड़ा","पिछड़ा","अनुसुचित जाति","सामान्य","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","सामान्य","पिछड़ा","सामान्य","सामान्य","सामान्य","सामान्य","सामान्य","पिछड़ा"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?=SP\u003cbr\u003eCategory=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SP","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"SP","offsetgroup":"SP","orientation":"v","showlegend":true,"x":["अनुसुचित जाति","पिछड़ा","पिछड़ा","सामान्य","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","सामान्य","सामान्य","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","मुस्लिम","पिछड़ा","सामान्य","पिछड़ा","अनुसुचित जाति","सामान्य","अनुसुचित जाति","अनुसुचित जाति"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?=INC\u003cbr\u003eCategory=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"INC","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"INC","offsetgroup":"INC","orientation":"v","showlegend":true,"x":["अनुसुचितजन जाति","सामान्य","अनुसुचित जाति","अनुसुचित जाति","पिछड़ा","अनुसुचित जाति ...

# %%
df.columns
# Out:
# Index(['name', 'creation', 'User', 'Location', 'Audio', 'Booth No',
#        'Area/Village/Town', 'Name', 'Father Name', 'Mobile No', 'Age',
#        'Gender', 'Education', 'Occupation', 'Category', 'Caste',
#        'Other (other_que_11)',
#        '1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?',
#        '2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?',
#        '3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?',
#        '4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?',
#        '5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?',
#        '6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?',
#        '7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?',
#        'Remark', 'Vendor Name'],
#       dtype='object')

# %%
fig5 = px.pie(
    df,
    names="5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?",
    title="उम्मीदवार के अनुसार वोट पसंद"
)

fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a96e7332-d83c-43e6-8517-f1c1d9a15ced" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a96e7332-d83c-43e6-8517-f1c1d9a15ced")) {                    Plotly.newPlot(                        "a96e7332-d83c-43e6-8517-f1c1d9a15ced",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["ठाकुर प्रसाद यादव-BSP","ठाकुर प्रसाद यादव-BSP","Other","Other","धीरेन्द्र बहादुर सिंह - BJP","धीरेन्द्र बहादुर सिंह - BJP","अमित सिंह वत्स-BJP","ठाकुर प्रसाद यादव-BSP","धीरेन्द्र बहादुर सिंह - BJP","देवेन्द्र प्रताप सिंह-SP","धीरेन्द्र बहादुर सिंह - BJP","देवेन्द्र प्रताप सिंह-SP","देवेन्द्र प्रताप सिंह-SP","सुधा द्विवेदी-INC","सुधा द्विवेदी-INC","धीरेन्द्र बहादुर सिंह - BJP","धीरेन्द्र बहादुर सिंह - BJP","देवेन्द्र प्रताप सिंह-SP","धीरेन्द्र बहादुर सिंह - BJP","Other","Other","Other","अमित सिंह वत्स-BJP","देवेन्द्र प्रताप सिंह-SP","Other","देवेन्द्र प्रताप सिंह-SP","Other","ठाकुर प्रसाद यादव-BSP","धीरेन्द्र बहादुर सिंह - BJP","ठाकुर प्रसाद यादव-BSP","ठाकुर प्रसाद यादव-BSP","धीरेन्द्र बहादुर सिंह - BJP","ठाकुर प्रसाद यादव-BSP","ठाकुर प्रसाद यादव-BSP","ठाकुर प्रसाद यादव-BSP","ठाकुर प्रसाद यादव-BSP","ठाकुर प्रस
type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl", ...

# %%
df.columns
# Out:
# Index(['name', 'creation', 'User', 'Location', 'Audio', 'Booth No',
#        'Area/Village/Town', 'Name', 'Father Name', 'Mobile No', 'Age',
#        'Gender', 'Education', 'Occupation', 'Category', 'Caste',
#        'Other (other_que_11)',
#        '1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?',
#        '2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?',
#        '3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?',
#        '4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?',
#        '5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?',
#        '6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?',
#        '7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?',
#        'Remark', 'Vendor Name'],
#       dtype='object')

# %%
df["6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?"].value_counts()
# Out:
# 6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?
# BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)    49
# पता नहीं                                       33
# BSP- सरकार(मायावती)  (2007-2012)               27
# SP- सरकार (अखिलेश यादव) (2012-2017)            25
# Name: count, dtype: int64

# %%
fig7=px.histogram(df,x="6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?",title="Which government history was legendary")
fig7
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="70861c4d-7e13-4b32-9bf1-a27c5a34fe02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70861c4d-7e13-4b32-9bf1-a27c5a34fe02")) {                    Plotly.newPlot(                        "70861c4d-7e13-4b32-9bf1-a27c5a34fe02",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["BSP- सरकार(मायावती)  (2007-2012)","BSP- सरकार(मायावती)  (2007-2012)","पता नहीं","पता नहीं","BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)","BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)","BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)","SP- सरकार (अखिलेश यादव) (2012-2017)","BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)","SP- सरकार (अखिलेश यादव) (2012-2017)","BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)","SP- सरकार (अखिलेश यादव) (2012-2017)","SP- सरकार (अखिलेश यादव) (2012-2017)","BSP- सरकार(मायावती)  (2007-2012)","SP- सरकार (अखिलेश यादव) (2012-2017)","BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)","BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)","SP- सरकार (अखिलेश यादव) (2012-2017)","BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)","BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)","BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)","पता नह