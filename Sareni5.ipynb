# %% [markdown]
# <a href="https://colab.research.google.com/github/saxena431/Sareni2/blob/main/Sareni5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
df=pd.read_excel("/content/Try2.xlsx")

# %%
df.head(1)
# Out:
#                   name                 creation                         User  \
# 0  Sareni_Survey000224  03/13/2026, 03:21:33 PM  sanataniradmohan@gmail.coml
#
#                                             Location       Audio  Booth No  \
# 0  {"type":"FeatureCollection","features":[{"type...  View Audio       108
#
#   Area/Village/Town       Name Father Name   Mobile No  ...  \
# 0         rasigoan   matilesh    Rajkumar   8737005032  ...
#
#    Other (other_que_11)  \
# 0                   NaN
#
#   1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?  \
# 0                                               नाली
#
#   2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?  \
# 0                                 बेरोजगारी
#
#   3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?  \
# 0                                   बिल्कुल नहीं
#
#   4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  \
# 0                                                BJP
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 26 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   name                                                                                 184 non-null    object
#  1   creation                                                                             184 non-null    object
#  2   User                                                                                 184 non-null    object
#  3   Location                                                                             184 non-null    object
#  4   Audio                                                                                184 non-null    object
# ...

# %%
df.describe()
# Out:
#          Booth No     Mobile No         Age
# count  184.000000  1.840000e+02  184.000000
# mean   105.842391  8.577775e+09   46.516304
# std      8.830037  1.103399e+09   15.988034
# min      7.000000  0.000000e+00   19.000000
# 25%    102.000000  7.885510e+09   32.000000
# 50%    105.000000  8.874852e+09   46.500000
# 75%    110.000000  9.451828e+09   59.000000
# max    117.000000  9.988513e+09   88.000000

# %%
df.isna().sum()
# Out:
# name                                                                                     0
# creation                                                                                 0
# User                                                                                     0
# Location                                                                                 0
# Audio                                                                                    0
# Booth No                                                                                 0
# Area/Village/Town                                                                        0
# Name                                                                                     0
# Father Name                                                                              0
# Mobile No                                                                                0
# ...

# %%
df.fillna('0')
# Out:
#                     name                 creation  \
# 0    Sareni_Survey000224  03/13/2026, 03:21:33 PM
# 1    Sareni_Survey000223  03/13/2026, 03:20:40 PM
# 2    Sareni_Survey000222  03/13/2026, 03:14:40 PM
# 3    Sareni_Survey000221  03/13/2026, 03:09:36 PM
# 4    Sareni_Survey000220  03/13/2026, 03:03:17 PM
# ..                   ...                      ...
# 179  Sareni_Survey000021  03/10/2026, 09:59:29 AM
# 180  Sareni_Survey000020  03/10/2026, 09:49:23 AM
# 181  Sareni_Survey000018  03/10/2026, 09:33:44 AM
# 182  Sareni_Survey000017  03/10/2026, 09:28:06 AM
# 183  Sareni_Survey000016  03/10/2026, 09:17:18 AM
#
#                               User  \
# 0      sanataniradmohan@gmail.coml
# 1    diwakarshukla941586@gmail.com
# 2    diwakarshukla941586@gmail.com
# 3    diwakarshukla941586@gmail.com
# 4    diwakarshukla941586@gmail.com
# ..                             ...
# 179    sanataniradmohan@gmail.coml
# 180    sanataniradmohan@gmail.coml
# ...

# %%
df.isna().sum()
# Out:
# name                                                                                     0
# creation                                                                                 0
# User                                                                                     0
# Location                                                                                 0
# Audio                                                                                    0
# Booth No                                                                                 0
# Area/Village/Town                                                                        0
# Name                                                                                     0
# Father Name                                                                              0
# Mobile No                                                                                0
# ...

# %%
print("Rows :",df.shape[0])
print("Columns :",df.shape[1])
# Out:
# Rows : 184
# Columns : 26

# %%
df.columns
# Out:
# Index(['name', 'creation', 'User', 'Location', 'Audio', 'Booth No',
#        'Area/Village/Town', 'Name', 'Father Name', 'Mobile No', 'Age',
#        'Gender', 'Education', 'Occupation', 'Category', 'Caste',
#        'Other (other_que_11)',
#        '1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?',
#        '2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?',
#        '3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?',
#        '4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?',
#        '5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?',
#        '6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?',
#        '7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?',
#        'Remark', 'Vendor Name'],
#       dtype='object')

# %%
df["Gender"].value_counts()
# Out:
# Gender
# MALE      119
# FEMALE     65
# Name: count, dtype: int64

# %%
sns.countplot(x="Gender",data=df,palette='dark')
# Out:
# /tmp/ipykernel_559/344270840.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df["Education"].value_counts()
# Out:
# Education
# Other            78
# 10th             54
# Graduate         21
# 12th             21
# Post Graduate    10
# Name: count, dtype: int64

# %%
sns.countplot(x="Education",data=df,palette='dark')
# Out:
# /tmp/ipykernel_559/1174299621.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <Axes: xlabel='Education', ylabel='count'>

# %%
df["Category"].value_counts()
# Out:
# Category
# पिछड़ा             92
# सामान्य            44
# अनुसुचित जाति      40
# मुस्लिम             6
# अनुसुचितजन जाति     1
# अन्य                1
# Name: count, dtype: int64

# %%
fig3=px.histogram(df,x="Category",barmode='group')
fig3.update_layout(xaxis_title="Category",yaxis_title="Count",title="Chart for Category")
fig3
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.columns
# Out:
# Index(['name', 'creation', 'User', 'Location', 'Audio', 'Booth No',
#        'Area/Village/Town', 'Name', 'Father Name', 'Mobile No', 'Age',
#        'Gender', 'Education', 'Occupation', 'Category', 'Caste',
#        'Other (other_que_11)',
#        '1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?',
#        '2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?',
#        '3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?',
#        '4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?',
#        '5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?',
#        '6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?',
#        '7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?',
#        'Remark', 'Vendor Name'],
#       dtype='object')

# %%
df["Occupation"].value_counts()
# Out:
# Occupation
# Farmer         85
# Other          69
# Private Job    19
# Business        6
# Shopkeepers     3
# Gov. Job        2
# Name: count, dtype: int64

# %%
sns.countplot(x="Occupation",data=df,palette='dark')
# Out:
# /tmp/ipykernel_559/2501655489.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df["Caste"].value_counts()
# Out:
# Caste
# Others              58
# हरिजन (जाटव)        50
# ब्राहमण             40
# नाई/सविता            7
# खाती / बढ़ई           7
# मुस्लिम              6
# यादव                 4
# तेली/ गुप्ता         2
# कुम्हार              2
# ठाकुर / राजपुत       2
# पाल                  1
# लुहार                1
# लोधी                 1
# मौर्या / कुशवाहा     1
# चौहान                1
# कुर्मी / पटेल        1
# Name: count, dtype: int64

# %%
fig2=px.histogram(df,x="Caste",color="Gender",barmode="group")
fig2.update_layout(xaxis_title="Caste",yaxis_title="Gender",title="Chart for Gender and Caste")
fig2
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig4=px.histogram(df,x="Caste",barmode="group")
fig4.update_layout(xaxis_title="Caste",yaxis_title="Gender",title="Chart for Maximum Caste")
fig4
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df["4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?"].value_counts()
# Out:
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?
# BJP      62
# Other    51
# BSP      31
# SP       24
# INC      16
# Name: count, dtype: int64

# %%
sns.countplot(x="4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?",data=df,palette='dark')
plt.xlabel("Party")
plt.ylabel("Voting Count")
# Out:
# /tmp/ipykernel_559/2483409755.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# Text(0, 0.5, 'Voting Count')

# %%
df.groupby("Booth No")["4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?"].value_counts().unstack(fill_value=0)
# Out:
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  BJP  \
# Booth No
# 7                                                                            0
# 100                                                                          2
# 101                                                                          5
# 102                                                                          8
# 103                                                                          1
# 104                                                                          4
# 105                                                                          6
# 106                                                                          7
# 108                                                                          4
# 109                                                                          7
# 110                                                                         11
# ...

# %%
df.groupby("Caste")["4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?"].value_counts(). unstack(fill_value=0)
# Out:
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  BJP  \
# Caste
# Others                                                                      17
# कुम्हार                                                                      1
# कुर्मी / पटेल                                                                0
# खाती / बढ़ई                                                                   4
# चौहान                                                                        0
# ठाकुर / राजपुत                                                               1
# तेली/ गुप्ता                                                                 2
# नाई/सविता                                                                    3
# पाल                                                                          1
# ब्राहमण                                                                     20
# मुस्लिम                                                                      2
# ...

# %%
df.groupby("Category")["4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?"].value_counts().unstack(fill_value=0)
# Out:
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  BJP  \
# Category
# अनुसुचित जाति                                                                2
# अनुसुचितजन जाति                                                              0
# अन्य                                                                         0
# पिछड़ा                                                                      37
# मुस्लिम                                                                      2
# सामान्य                                                                     21
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  BSP  \
# Category
# अनुसुचित जाति                                                                5
# अनुसुचितजन जाति                                                              0
# अन्य                                                                         0
# ...

# %%
fig = px.histogram(
    df,
    x="Category",
    color="4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?",
    barmode="group"
)
fig.update_layout(
    xaxis_title="Category",
    yaxis_title="Count",
    title="पार्टी पसंद श्रेणी के अनुसार"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.columns
# Out:
# Index(['name', 'creation', 'User', 'Location', 'Audio', 'Booth No',
#        'Area/Village/Town', 'Name', 'Father Name', 'Mobile No', 'Age',
#        'Gender', 'Education', 'Occupation', 'Category', 'Caste',
#        'Other (other_que_11)',
#        '1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?',
#        '2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?',
#        '3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?',
#        '4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?',
#        '5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?',
#        '6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?',
#        '7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?',
#        'Remark', 'Vendor Name'],
#       dtype='object')

# %%
fig5 = px.pie(
    df,
    names="5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?",
    title="उम्मीदवार के अनुसार वोट पसंद"
)

fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig6 = px.pie(
    df,
    names="7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?",
    title="UP CM"
)

fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.columns
# Out:
# Index(['name', 'creation', 'User', 'Location', 'Audio', 'Booth No',
#        'Area/Village/Town', 'Name', 'Father Name', 'Mobile No', 'Age',
#        'Gender', 'Education', 'Occupation', 'Category', 'Caste',
#        'Other (other_que_11)',
#        '1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?',
#        '2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?',
#        '3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?',
#        '4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?',
#        '5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?',
#        '6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?',
#        '7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?',
#        'Remark', 'Vendor Name'],
#       dtype='object')

# %%
df["6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?"].value_counts()
# Out:
# 6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?
# BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)    75
# पता नहीं                                       44
# BSP- सरकार(मायावती)  (2007-2012)               37
# SP- सरकार (अखिलेश यादव) (2012-2017)            28
# Name: count, dtype: int64

# %%
fig7=px.histogram(df,x="6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?",title="Which government history was legendary")
fig7
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
