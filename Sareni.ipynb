# %% [markdown]
# <a href="https://colab.research.google.com/github/saxena431/Sareni2/blob/main/Sareni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
df=pd.read_excel("/content/Try2.xlsx")

# %%
df.head(1)
# Out:
#                   name                 creation  \
# 0  Sareni_Survey000153  03/12/2026, 11:25:03 AM
#
#                             User  \
# 0  diwakarshukla941586@gmail.com
#
#                                             Location       Audio  Booth No  \
# 0  {"type":"FeatureCollection","features":[{"type...  View Audio       106
#
#   Area/Village/Town           Name Father Name   Mobile No  ...  \
# 0      Gopali kheda  Hanuman yadav  Chandi lal  7080956217  ...
#
#    Other (other_que_11)  \
# 0                   NaN
#
#   1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?  \
# 0                                          बेरोजगारी
#
#   2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?  \
# 0                                 बेरोजगारी
#
#   3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?  \
# 0                                   बिल्कुल नहीं
#
#   4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  \
# 0                                                 SP
#
#   5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?  \
# 0                           देवेन्द्र प्रताप सिंह-SP
#
#   6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?  \
# 0                SP- सरकार (अखिलेश यादव) (2012-2017)
#
#   7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?  \
# 0                                        अखिलेश यादव
#
#             Remark Vendor Name
# 0  Nali ki samasya      Annand
#
# [1 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 26 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   name                                                                                 122 non-null    object
#  1   creation                                                                             122 non-null    object
#  2   User                                                                                 122 non-null    object
#  3   Location                                                                             122 non-null    object
#  4   Audio                                                                                122 non-null    object
#  5   Booth No                                                                             122 non-null    int64
#  6   Area/Village/Town                                                                    122 non-null    object
#  7   Name                                                                                 122 non-null    object
#  8   Father Name                                                                          122 non-null    object
#  9   Mobile No                                                                            122 non-null    int64
#  10  Age                                                                                  122 non-null    int64
#  11  Gender                                                                               122 non-null    object
#  12  Education                                                                            122 non-null    object
#  13  Occupation                                                                           122 non-null    object
#  14  Category                                                                             122 non-null    object
#  15  Caste                                                                                122 non-null    object
#  16  Other (other_que_11)                                                                 34 non-null     object
#  17  1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?  122 non-null    object
#  18  2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?                                            122 non-null    object
#  19  3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?                                       122 non-null    object
#  20  4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?            122 non-null    object
#  21  5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?         122 non-null    object
#  22  6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?                                122 non-null    object
#  23  7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?                122 non-null    object
#  24  Remark                                                                               122 non-null    object
#  25  Vendor Name                                                                          122 non-null    object
# dtypes: int64(3), object(23)
# memory usage: 24.9+ KB

# %%
df.describe()
# Out:
#          Booth No     Mobile No         Age
# count  122.000000  1.220000e+02  122.000000
# mean   104.836066  8.584817e+09   46.590164
# std      5.167221  9.011482e+08   15.811782
# min    100.000000  6.393464e+09   19.000000
# 25%    101.250000  7.889655e+09   32.000000
# 50%    103.000000  8.826749e+09   48.000000
# 75%    105.000000  9.331878e+09   58.000000
# max    117.000000  9.988513e+09   88.000000

# %%
df.isna().sum()
# Out:
# name                                                                                    0
# creation                                                                                0
# User                                                                                    0
# Location                                                                                0
# Audio                                                                                   0
# Booth No                                                                                0
# Area/Village/Town                                                                       0
# Name                                                                                    0
# Father Name                                                                             0
# Mobile No                                                                               0
# Age                                                                                     0
# Gender                                                                                  0
# Education                                                                               0
# Occupation                                                                              0
# Category                                                                                0
# Caste                                                                                   0
# Other (other_que_11)                                                                   88
# 1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?     0
# 2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?                                               0
# 3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?                                          0
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?               0
# 5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?            0
# 6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?                                   0
# 7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?                   0
# Remark                                                                                  0
# Vendor Name                                                                             0
# dtype: int64

# %%
df.fillna('0')
# Out:
#                     name                 creation  \
# 0    Sareni_Survey000153  03/12/2026, 11:25:03 AM
# 1    Sareni_Survey000152  03/12/2026, 11:19:50 AM
# 2    Sareni_Survey000151  03/12/2026, 10:02:45 AM
# 3    Sareni_Survey000150  03/12/2026, 09:58:20 AM
# 4    Sareni_Survey000149  03/12/2026, 09:39:50 AM
# ..                   ...                      ...
# 117  Sareni_Survey000021  03/10/2026, 09:59:29 AM
# 118  Sareni_Survey000020  03/10/2026, 09:49:23 AM
# 119  Sareni_Survey000018  03/10/2026, 09:33:44 AM
# 120  Sareni_Survey000017  03/10/2026, 09:28:06 AM
# 121  Sareni_Survey000016  03/10/2026, 09:17:18 AM
#
#                               User  \
# 0    diwakarshukla941586@gmail.com
# 1    diwakarshukla941586@gmail.com
# 2    diwakarshukla941586@gmail.com
# 3    diwakarshukla941586@gmail.com
# 4    diwakarshukla941586@gmail.com
# ..                             ...
# 117    sanataniradmohan@gmail.coml
# 118    sanataniradmohan@gmail.coml
# 119  diwakarshukla941586@gmail.com
# 120    sanataniradmohan@gmail.coml
# 121    sanataniradmohan@gmail.coml
#
#                                               Location       Audio  Booth No  \
# 0    {"type":"FeatureCollection","features":[{"type...  View Audio       106
# 1    {"type":"FeatureCollection","features":[{"type...  View Audio       106
# 2    {"type":"FeatureCollection","features":[{"type...  View Audio       106
# 3    {"type":"FeatureCollection","features":[{"type...  View Audio       106
# 4    {"type":"FeatureCollection","features":[{"type...  View Audio       106
# ..                                                 ...         ...       ...
# 117  {"type":"FeatureCollection","features":[{"type...  View Audio       101
# 118  {"type":"FeatureCollection","features":[{"type...  View Audio       101
# 119         {"type":"FeatureCollection","features":[]}  View Audio       102
# 120  {"type":"FeatureCollection","features":[{"type...  View Audio       101
# 121  {"type":"FeatureCollection","features":[{"type...  View Audio       101
#
#     Area/Village/Town           Name      Father Name   Mobile No  ...  \
# 0        Gopali kheda  Hanuman yadav       Chandi lal  7080956217  ...
# 1       gopali kahera    rvi shankar        baj natha  9794899214  ...
# 2       gopali kahera    kapil rawat            Saroj  7753912164  ...
# 3        Gopali kheda     Dharmendra       Anil kumar  8018451626  ...
# 4        Gopali kheda         Ramesh            Angnu  8858694311  ...
# ..                ...            ...              ...         ...  ...
# 117          cheulaha      anitadevi       ajay kumar  8115562135  ...
# 118          cheulaha      shree pal         shitaram  7054056914  ...
# 119         cheulaha       ram badan  sangatha prasad  8736094315  ...
# 120          cheulaha         budhai            parag  8953867840  ...
# 121          cheulaha   rahul mshrai    rajesh meshra  7518709382  ...
#
#      Other (other_que_11)  \
# 0                       0
# 1                       0
# 2                       0
# 3                    gond
# 4                    Gond
# ..                    ...
# 117                     0
# 118                     0
# 119                 dhobi
# 120                     0
# 121                     0
#
#     1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?  \
# 0                                            बेरोजगारी
# 1                                            बेरोजगारी
# 2                                            आवारा पशु
# 3                                                  सड़क
# 4                                         पीने का पानी
# ..                                                 ...
# 117                                           साफ.सफाई
# 118                                       पीने का पानी
# 119                                       पीने का पानी
# 120                                           साफ.सफाई
# 121                               स्वास्थ्य - हॉस्पिटल
#
#     2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?  \
# 0                                   बेरोजगारी
# 1                                   बेरोजगारी
# 2                                   आवारा पशु
# 3                                   बेरोजगारी
# 4                                   बेरोजगारी
# ..                                        ...
# 117                                     Other
# 118                                 बेरोजगारी
# 119                                 उधोग धंदे
# 120                                 बेरोजगारी
# 121                                 बेरोजगारी
#
#     3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?  \
# 0                                     बिल्कुल नहीं
# 1                                     बिल्कुल नहीं
# 2                                      हाँ खुश हैं
# 3                                     बिल्कुल नहीं
# 4                                     बिल्कुल नहीं
# ..                                             ...
# 117                                    हाँ खुश हैं
# 118                                      थोडा बहुत
# 119                                   बिल्कुल नहीं
# 120                               कुछ कह नहीं सकते
# 121                                   बिल्कुल नहीं
#
#     4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  \
# 0                                                   SP
# 1                                                  INC
# 2                                                  INC
# 3                                                  BJP
# 4                                                  BJP
# ..                                                 ...
# 117                                                BJP
# 118                                                INC
# 119                                                INC
# 120                                              Other
# 121                                              Other
#
#     5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?  \
# 0                             देवेन्द्र प्रताप सिंह-SP
# 1                                    सुधा द्विवेदी-INC
# 2                                    सुधा द्विवेदी-INC
# 3                          धीरेन्द्र बहादुर सिंह - BJP
# 4                          धीरेन्द्र बहादुर सिंह - BJP
# ..                                                 ...
# 117                                              Other
# 118                                  सुधा द्विवेदी-INC
# 119                                  सुधा द्विवेदी-INC
# 120                                 अमित सिंह वत्स-BJP
# 121                        धीरेन्द्र बहादुर सिंह - BJP
#
#     6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?  \
# 0                  SP- सरकार (अखिलेश यादव) (2012-2017)
# 1                     BSP- सरकार(मायावती)  (2007-2012)
# 2                  SP- सरकार (अखिलेश यादव) (2012-2017)
# 3          BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)
# 4          BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)
# ..                                                 ...
# 117        BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)
# 118                SP- सरकार (अखिलेश यादव) (2012-2017)
# 119                                           पता नहीं
# 120        BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)
# 121        BJP- सरकार (योगी आदित्यनाथ ) (2017-Present)
#
#     7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?  \
# 0                                          अखिलेश यादव
# 1                                          अखिलेश यादव
# 2                                          अखिलेश यादव
# 3                                       योगी आदित्यनाथ
# 4                                       योगी आदित्यनाथ
# ..                                                 ...
# 117                                     योगी आदित्यनाथ
# 118                                        अखिलेश यादव
# 119                                     सुश्री.मायावती
# 120                                     योगी आदित्यनाथ
# 121                                     योगी आदित्यनाथ
#
#                                               Remark Vendor Name
# 0                                    Nali ki samasya      Annand
# 1                                      gopali kahera      anannd
# 2                             Aawara pasu ki samasya      Anannd
# 3                                    Rood ki samasya      Aanand
# 4                                      Rod kisamsaya      Anaand
# ..                                               ...         ...
# 117                                nali ki saf safai      anand
# 118                                  pani  saf safai       anand
# 119                                  pani ki samsaya     diwakar
# 120  nali rod ki saf tal saf safai bhe nehi hoti hai       anand
# 121                                         pani ki        anand
#
# [122 rows x 26 columns]

# %%
df.isna().sum()
# Out:
# name                                                                                    0
# creation                                                                                0
# User                                                                                    0
# Location                                                                                0
# Audio                                                                                   0
# Booth No                                                                                0
# Area/Village/Town                                                                       0
# Name                                                                                    0
# Father Name                                                                             0
# Mobile No                                                                               0
# Age                                                                                     0
# Gender                                                                                  0
# Education                                                                               0
# Occupation                                                                              0
# Category                                                                                0
# Caste                                                                                   0
# Other (other_que_11)                                                                   88
# 1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?     0
# 2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?                                               0
# 3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?                                          0
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?               0
# 5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?            0
# 6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?                                   0
# 7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?                   0
# Remark                                                                                  0
# Vendor Name                                                                             0
# dtype: int64

# %%
print("Rows :",df.shape[0])
print("Columns :",df.shape[1])
# Out:
# Rows : 122
# Columns : 26

# %%
df.columns
# Out:
# Index(['name', 'creation', 'User', 'Location', 'Audio', 'Booth No',
#        'Area/Village/Town', 'Name', 'Father Name', 'Mobile No', 'Age',
#        'Gender', 'Education', 'Occupation', 'Category', 'Caste',
#        'Other (other_que_11)',
#        '1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?',
#        '2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?',
#        '3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?',
#        '4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?',
#        '5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?',
#        '6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?',
#        '7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?',
#        'Remark', 'Vendor Name'],
#       dtype='object')

# %%
df["Gender"].value_counts()
# Out:
# Gender
# MALE      82
# FEMALE    40
# Name: count, dtype: int64

# %%
sns.countplot(x="Gender",data=df,palette='dark')
# Out:
# /tmp/ipykernel_1244/344270840.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Gender",data=df,palette='dark')
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df["Education"].value_counts()
# Out:
# Education
# Other            49
# 10th             36
# Graduate         14
# 12th             13
# Post Graduate    10
# Name: count, dtype: int64

# %%
sns.countplot(x="Education",data=df,palette='dark')
# Out:
# /tmp/ipykernel_1244/1174299621.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Education",data=df,palette='dark')
# <Axes: xlabel='Education', ylabel='count'>

# %%
df["Category"].value_counts()
# Out:
# Category
# पिछड़ा             59
# अनुसुचित जाति      31
# सामान्य            28
# मुस्लिम             2
# अनुसुचितजन जाति     1
# अन्य                1
# Name: count, dtype: int64

# %%
fig3=px.histogram(df,x="Category",barmode='group')
fig3.update_layout(xaxis_title="Category",yaxis_title="Count",title="Chart for Category")
fig3
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="415eff69-3687-4817-8808-02f402488bcc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("415eff69-3687-4817-8808-02f402488bcc")) {                    Plotly.newPlot(                        "415eff69-3687-4817-8808-02f402488bcc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Category=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["पिछड़ा","अनुसुचितजन जाति","सामान्य","पिछड़ा","पिछड़ा","सामान्य","पिछड़ा","सामान्य","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","अनुसुचित जाति","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","सामान्य","पिछड़ा","पिछड़ा","पिछड़ा","अनुसुचित जाति","पिछड़ा","पिछड़ा","अनुसुचित जाति","पिछड़ा","अनुसुचित जाति","सामान्य","अनुसुचित जाति","अनुसुचित जाति","पिछड़ा","पिछड़ा","अनुसुचित जाति","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","पिछड़ा","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","सामान्य","सामान्य","सामान्य","सामान्य","पिछड़ा","पिछड़ा","पिछड़ा","सामान्य","पिछड़ा","सामान्य","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","मुस्लिम","पिछड़ा","अनुसुचित जाति","सामान्य","पिछड़ा","अनुसुचित जाति","पिछड़ा","सामान्य","पिछड़ा","सामान्य","अनुसुचित जाति","पिछड़ा","पिछड़ा","पिछड़ा","सामान्य","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","अनुसुचित जाति","अनुसुचित जाति","पिछड़ा","पिछड़ा","पिछड़ा","अन्य","पिछड़ा","पिछड़ा","अनुसुचित जाति","पिछड़ा","पिछड़ा","सामान्य","अनुसुचित जाति","सामान्य","पिछड़ा","सामान्य","अनुसुचित जाति","सामान्य","सामान्य","सामान्य","सामान्य","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","सामान्य","सामान्य","अनुसुचित जाति","अनुसुचित जाति","मुस्लिम","सामान्य","सामान्य","सामान्य","अनुसुचित जाति","पिछड़ा","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","अनुसुचित जाति","सामान्य"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth" ...

# %%
df.columns
# Out:
# Index(['name', 'creation', 'User', 'Location', 'Audio', 'Booth No',
#        'Area/Village/Town', 'Name', 'Father Name', 'Mobile No', 'Age',
#        'Gender', 'Education', 'Occupation', 'Category', 'Caste',
#        'Other (other_que_11)',
#        '1.निम्न में से कौन सी स्थानीय समस्या आपके दैनिक जीवन को सर्वाधिक प्रभावित करती है ?',
#        '2.आपके जिले में सबसे बड़ा मुद्दा क्या है ?',
#        '3.आप अपने वर्तमान विधायक के कार्यो से खुश हैं?',
#        '4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?',
#        '5.आप आने वाले विधानसभा चुनाव 2027 मे किस उम्मीदवार को अपना वोट देना चाहेगें?',
#        '6.आपको किस राज्य सरकार का कार्यकाल ज्यादा अच्छा लगा ?',
#        '7.आप किन्हे उत्तर प्रदेश के अगले मुख्यमंत्री के रूप मे देखना चाहेंगे?',
#        'Remark', 'Vendor Name'],
#       dtype='object')

# %%
df["Occupation"].value_counts()
# Out:
# Occupation
# Farmer         60
# Other          40
# Private Job    13
# Business        6
# Shopkeepers     2
# Gov. Job        1
# Name: count, dtype: int64

# %%
sns.countplot(x="Occupation",data=df,palette='dark')
# Out:
# /tmp/ipykernel_1244/2501655489.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Occupation",data=df,palette='dark')
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df["Caste"].value_counts()
# Out:
# Caste
# Others            47
# हरिजन (जाटव)      31
# ब्राहमण           25
# खाती / बढ़ई         7
# नाई/सविता          4
# यादव               3
# मुस्लिम            2
# ठाकुर / राजपुत     2
# तेली/ गुप्ता       1
# Name: count, dtype: int64

# %%
fig2=px.histogram(df,x="Caste",color="Gender",barmode="group")
fig2.update_layout(xaxis_title="Caste",yaxis_title="Gender",title="Chart for Gender and Caste")
fig2
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="becebbd9-1e5d-416a-9524-774573980ce6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("becebbd9-1e5d-416a-9524-774573980ce6")) {                    Plotly.newPlot(                        "becebbd9-1e5d-416a-9524-774573980ce6",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Gender=MALE\u003cbr\u003eCaste=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MALE","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"MALE","offsetgroup":"MALE","orientation":"v","showlegend":true,"x":["यादव","नाई\u002fसविता","ब्राहमण","Others","Others","Others","ब्राहमण","नाई\u002fसविता","Others","खाती \u002f बढ़ई","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","ब्राहमण","Others","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","Others","Others","ब्राहमण","ब्राहमण","ब्राहमण","ब्राहमण","हरिजन (जाटव)","Others","हरिजन (जाटव)","ब्राहमण","हरिजन (जाटव)","ब्राहमण","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","Others","मुस्लिम","Others","Others","ब्राहमण","यादव","ब्राहमण","Others","ठाकुर \u002f राजपुत","हरिजन (जाटव)","Others","खाती \u002f बढ़ई","ब्राहमण","Others","तेली\u002f गुप्ता","खाती \u002f बढ़ई","Others","खाती \u002f बढ़ई","Others","ब्राहमण","ब्राहमण","Others","ब्राहमण","Others","ब्राहमण","ब्राहमण","हरिजन (जाटव)","Others","ब्राहमण","ठाकुर \u002f राजपुत","Others","हरिजन (जाटव)","मुस्लिम","ब्राहमण","ब्राहमण","नाई\u002fसविता","Others","Others","Others","Others","ब्राहमण"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Gender=FEMALE\u003cbr\u003eCaste=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"FEMALE","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"FEMALE","offsetgroup":"FEMALE","orientation":"v","showlegend":true,"x":["ब्राहमण","Others","Others","यादव","Others","Others","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","Others","हरिजन (जाटव)","Others","हरिजन (जाटव)","Others","हरिजन (जाटव)","हरिजन (जाटव)","Others","Others","नाई\u002fसविता","Others","Others","Others","Others","Others","Others","Others","Others","Others","Others","खाती \u002f बढ़ई","खाती \u002f बढ़ई","Others","खाती \u002f बढ़ई","Others","ब्राहमण","ब्राहमण","Others","ब्राहमण","Others"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl" ...

# %%
fig4=px.histogram(df,x="Caste",barmode="group")
fig4.update_layout(xaxis_title="Caste",yaxis_title="Gender",title="Chart for Maximum Caste")
fig4
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2c9a1c9f-6e5f-4d9d-a8a9-926dd1712865" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c9a1c9f-6e5f-4d9d-a8a9-926dd1712865")) {                    Plotly.newPlot(                        "2c9a1c9f-6e5f-4d9d-a8a9-926dd1712865",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Caste=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["यादव","नाई\u002fसविता","ब्राहमण","Others","Others","ब्राहमण","Others","ब्राहमण","नाई\u002fसविता","Others","Others","यादव","Others","Others","Others","हरिजन (जाटव)","खाती \u002f बढ़ई","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","Others","हरिजन (जाटव)","हरिजन (जाटव)","Others","हरिजन (जाटव)","ब्राहमण","Others","हरिजन (जाटव)","हरिजन (जाटव)","Others","हरिजन (जाटव)","हरिजन (जाटव)","हरिजन (जाटव)","Others","हरिजन (जाटव)","Others","Others","Others","ब्राहमण","ब्राहमण","ब्राहमण","ब्राहमण","हरिजन (जाटव)","Others","हरिजन (जाटव)","ब्राहमण","हरिजन (जाटव)","ब्राहमण","हरिजन (जाटव)","हरिजन (जाटव)","नाई\u002fसविता","हरिजन (जाटव)","Others","Others","Others","Others","मुस्लिम","Others","Others","ब्राहमण","Others","Others","यादव","ब्राहमण","Others","ठाकुर \u002f राजपुत","हरिजन (जाटव)","Others","Others","खाती \u002f बढ़ई","ब्राहमण","Others","Others","Others","Others","Others","तेली\u002f गुप्ता","खाती \u002f बढ़ई","खाती \u002f बढ़ई","Others","खाती \u002f बढ़ई","खाती \u002f बढ़ई","Others","Others","खाती \u002f बढ़ई","ब्राहमण","Others","ब्राहमण","Others","ब्राहमण","Others","ब्राहमण","ब्राहमण","ब्राहमण","ब्राहमण","हरिजन (जाटव)","Others","Others","ब्राहमण","ठाकुर \u002f राजपुत","Others","हरिजन (जाटव)","मुस्लिम","ब्राहमण","ब्राहमण","ब्राहमण","Others","नाई\u002fसविता","Others","Others","Others","Others","ब्राहमण"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"out ...

# %%
df["4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?"].value_counts()
# Out:
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?
# Other    36
# BJP      34
# BSP      21
# SP       19
# INC      12
# Name: count, dtype: int64

# %%
sns.countplot(x="4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?",data=df,palette='dark')
plt.xlabel("Party")
plt.ylabel("Voting Count")
# Out:
# /tmp/ipykernel_1244/2483409755.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?",data=df,palette='dark')
# Text(0, 0.5, 'Voting Count')

# %%
df.groupby("Booth No")["4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?"].value_counts().unstack(fill_value=0)
# Out:
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  BJP  \
# Booth No
# 100                                                                          2
# 101                                                                          5
# 102                                                                          8
# 103                                                                          1
# 104                                                                          4
# 105                                                                          6
# 106                                                                          2
# 115                                                                          1
# 116                                                                          5
# 117                                                                          0
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  BSP  \
# Booth No
# 100                                                                          0
# 101                                                                          0
# 102                                                                          1
# 103                                                                          5
# 104                                                                          4
# 105                                                                          3
# 106                                                                          0
# 115                                                                          0
# 116                                                                          8
# 117                                                                          0
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  INC  \
# Booth No
# 100                                                                          0
# 101                                                                          2
# 102                                                                          5
# 103                                                                          0
# 104                                                                          3
# 105                                                                          0
# 106                                                                          2
# 115                                                                          0
# 116                                                                          0
# 117                                                                          0
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  Other  \
# Booth No
# 100                                                                            7
# 101                                                                           11
# 102                                                                            5
# 103                                                                            0
# 104                                                                            8
# 105                                                                            2
# 106                                                                            0
# 115                                                                            2
# 116                                                                            0
# 117                                                                            1
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  SP
# Booth No
# 100                                                                         1
# 101                                                                         3
# 102                                                                         3
# 103                                                                         4
# 104                                                                         4
# 105                                                                         0
# 106                                                                         1
# 115                                                                         1
# 116                                                                         1
# 117                                                                         1

# %%
df.groupby("Caste")["4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?"].value_counts(). unstack(fill_value=0)
# Out:
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  BJP  \
# Caste
# Others                                                                      14
# खाती / बढ़ई                                                                   4
# ठाकुर / राजपुत                                                               1
# तेली/ गुप्ता                                                                 1
# नाई/सविता                                                                    0
# ब्राहमण                                                                     10
# मुस्लिम                                                                      0
# यादव                                                                         0
# हरिजन (जाटव)                                                                 4
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  BSP  \
# Caste
# Others                                                                       6
# खाती / बढ़ई                                                                   0
# ठाकुर / राजपुत                                                               0
# तेली/ गुप्ता                                                                 0
# नाई/सविता                                                                    0
# ब्राहमण                                                                      0
# मुस्लिम                                                                      0
# यादव                                                                         0
# हरिजन (जाटव)                                                                15
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  INC  \
# Caste
# Others                                                                       6
# खाती / बढ़ई                                                                   1
# ठाकुर / राजपुत                                                               0
# तेली/ गुप्ता                                                                 0
# नाई/सविता                                                                    1
# ब्राहमण                                                                      1
# मुस्लिम                                                                      0
# यादव                                                                         0
# हरिजन (जाटव)                                                                 3
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  Other  \
# Caste
# Others                                                                        16
# खाती / बढ़ई                                                                     2
# ठाकुर / राजपुत                                                                 0
# तेली/ गुप्ता                                                                   0
# नाई/सविता                                                                      3
# ब्राहमण                                                                       10
# मुस्लिम                                                                        1
# यादव                                                                           0
# हरिजन (जाटव)                                                                   4
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  SP
# Caste
# Others                                                                      5
# खाती / बढ़ई                                                                  0
# ठाकुर / राजपुत                                                              1
# तेली/ गुप्ता                                                                0
# नाई/सविता                                                                   0
# ब्राहमण                                                                     4
# मुस्लिम                                                                     1
# यादव                                                                        3
# हरिजन (जाटव)                                                                5

# %%
df.groupby("Category")["4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?"].value_counts().unstack(fill_value=0)
# Out:
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  BJP  \
# Category
# अनुसुचित जाति                                                                2
# अनुसुचितजन जाति                                                              0
# अन्य                                                                         0
# पिछड़ा                                                                      21
# मुस्लिम                                                                      0
# सामान्य                                                                     11
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  BSP  \
# Category
# अनुसुचित जाति                                                                2
# अनुसुचितजन जाति                                                              0
# अन्य                                                                         0
# पिछड़ा                                                                      18
# मुस्लिम                                                                      0
# सामान्य                                                                      1
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  INC  \
# Category
# अनुसुचित जाति                                                                7
# अनुसुचितजन जाति                                                              1
# अन्य                                                                         0
# पिछड़ा                                                                       3
# मुस्लिम                                                                      0
# सामान्य                                                                      1
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  Other  \
# Category
# अनुसुचित जाति                                                                 15
# अनुसुचितजन जाति                                                                0
# अन्य                                                                           1
# पिछड़ा                                                                         9
# मुस्लिम                                                                        1
# सामान्य                                                                       10
#
# 4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?  SP
# Category
# अनुसुचित जाति                                                               5
# अनुसुचितजन जाति                                                             0
# अन्य                                                                        0
# पिछड़ा                                                                      8
# मुस्लिम                                                                     1
# सामान्य                                                                     5

# %%
fig = px.histogram(
    df,
    x="Category",
    color="4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?",
    barmode="group"
)
fig.update_layout(
    xaxis_title="Category",
    yaxis_title="Count",
    title="पार्टी पसंद श्रेणी के अनुसार"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5fa962eb-4bfb-4bbf-a0af-9778b90ef328" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5fa962eb-4bfb-4bbf-a0af-9778b90ef328")) {                    Plotly.newPlot(                        "5fa962eb-4bfb-4bbf-a0af-9778b90ef328",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?=SP\u003cbr\u003eCategory=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SP","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"SP","offsetgroup":"SP","orientation":"v","showlegend":true,"x":["पिछड़ा","सामान्य","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","सामान्य","सामान्य","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","मुस्लिम","पिछड़ा","सामान्य","पिछड़ा","अनुसुचित जाति","सामान्य","अनुसुचित जाति","अनुसुचित जाति"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?=INC\u003cbr\u003eCategory=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"INC","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"INC","offsetgroup":"INC","orientation":"v","showlegend":true,"x":["अनुसुचितजन जाति","सामान्य","अनुसुचित जाति","अनुसुचित जाति","पिछड़ा","अनुसुचित जाति","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?=BJP\u003cbr\u003eCategory=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BJP","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"BJP","offsetgroup":"BJP","orientation":"v","showlegend":true,"x":["पिछड़ा","पिछड़ा","पिछड़ा","सामान्य","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","सामान्य","अनुसुचित जाति","पिछड़ा","पिछड़ा","पिछड़ा","सामान्य","सामान्य","पिछड़ा","पिछड़ा","अनुसुचित जाति","सामान्य","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","सामान्य","पिछड़ा","सामान्य","सामान्य","सामान्य","सामान्य","सामान्य","पिछड़ा"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?=Other\u003cbr\u003eCategory=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"v","showlegend":true,"x":["पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","अनुसुचित जाति","अनुसुचित जाति","सामान्य","सामान्य","पिछड़ा","अनुसुचित जाति","सामान्य","पिछड़ा","सामान्य","पिछड़ा","पिछड़ा","अनुसुचित जाति","अनुसुचित जाति","अन्य","पिछड़ा","अनुसुचित जाति","पिछड़ा","सामान्य","अनुसुचित जाति","सामान्य","सामान्य","सामान्य","अनुसुचित जाति","अनुसुचित जाति","मुस्लिम","सामान्य","अनुसुचित जाति","पिछड़ा","अनुसुचित जाति","सामान्य"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"4.आप आने वाले विधानसभा चुनाव 2027 मे किस पार्टी को अपना वोट देना चाहेगें?=BSP\u003cbr\u003eCategory=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BSP","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"BSP","offsetgroup":"BSP","orientation":"v","showlegend":true,"x":["पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","सामान्य","पिछड़ा","पिछड़ा","अनुसुचित जाति","पिछड़ा","पिछड़ा","अनुसुचित जाति","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा","पिछड़ा"],"xaxis":"x","yaxis":"y","type":"hi ...
